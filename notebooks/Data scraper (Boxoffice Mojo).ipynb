# %%
import pandas as pd

movies_path = "data/movies.csv"
scraped_boxoffice_path = "data/boxoffice_mojo.csv"

# %%
movies = pd.read_csv(movies_path).convert_dtypes()
movies.head(50)
# Out:
#         id                           title  \
# 0      862                       Toy Story
# 1     8844                         Jumanji
# 2    15602                Grumpier Old Men
# 3    31357               Waiting to Exhale
# 4    11862     Father of the Bride Part II
# 5      949                            Heat
# 6    11860                         Sabrina
# 7    45325                    Tom and Huck
# 8     9091                    Sudden Death
# 9      710                       GoldenEye
# 10    9087          The American President
# 11   12110     Dracula: Dead and Loving It
# 12   21032                           Balto
# 13   10858                           Nixon
# 14    1408                Cutthroat Island
# 15     524                          Casino
# 16    4584           Sense and Sensibility
# 17       5                      Four Rooms
# 18    9273  Ace Ventura: When Nature Calls
# 19   11517                     Money Train
# 20    8012                      Get Shorty
# ...

# %%
boxoffice_mojo = pd.read_csv(scraped_boxoffice_path).convert_dtypes()
boxoffice_mojo.head(50)
# Out:
#                              title  \
# 0                          Jumanji
# 1      Father of the Bride Part II
# 2                             Heat
# 3                          Sabrina
# 4                 Grumpier Old Men
# 5                        Toy Story
# 6                     Tom and Huck
# 7           The American President
# 8      Dracula: Dead and Loving It
# 9                            Balto
# 10                           Nixon
# 11                Cutthroat Island
# 12               Waiting to Exhale
# 13                       GoldenEye
# 14                    Sudden Death
# 15                          Casino
# 16                      Four Rooms
# 17  Ace Ventura: When Nature Calls
# 18           Sense and Sensibility
# 19                     Money Train
# 20                      Get Shorty
# 21                         Copycat
# 22                         Othello
# 23                       Assassins
# 24                          Powder
# ...
