# %%
import joblib
import pandas as pd
import numpy as np
import altair as alt

DATA_FOLDER = "../data"

# %% [markdown]
# # Dataset merger
#
# This notebook aims to merge together all the various datasets that we collected regarding our task

# %% [markdown]
# First of all, we deduplicated the original dataset that we were given in the Made With ML challenge. There were 999 duplicated movies that had to be removed

# %%
deduplicated_original = pd.read_csv(f"{DATA_FOLDER}/deduplicated_movies.csv")

# %% [markdown]
# ## TMBD

# %% [markdown]
# We also have to deduplicate the dataset that we derived from the original dataset by scraping The Movies Database website.

# %%
tmdb = joblib.load(f"{DATA_FOLDER}/data.pkl").convert_dtypes().dropna()

# %%
duplicated_table = (tmdb["id"].value_counts() > 1).reset_index()
duplicated_idx = duplicated_table[duplicated_table["id"]]["index"]

# %%
def check_identical_df(df: pd.DataFrame) -> bool:
    """Checks whether a given dataframe contains identical rows"""

    test_row = df.iloc[0]
    return ((test_row.eq(df)).all()).all()

check_all_duplicates = (
    tmdb[tmdb["id"].isin(duplicated_idx)]
    .groupby("id")
    .apply(check_identical_df)
)
check_all_duplicates.all()
# Out:
# True

# %%
if check_all_duplicates.all():
    deduplicated_tmdb = tmdb.groupby("id").first().reset_index()

# %% [markdown]
# We can now merge the original movie and the information scraped from The Movies Database

# %%
original_tmdb_merge = deduplicated_original.merge(deduplicated_tmdb[["id", "new_revenue"]], on="id")

# %% [markdown]
# We have around 1200 new revenue information for various movies compared to the original dataset!

# %%
len(original_tmdb_merge[(original_tmdb_merge["revenue"] == 0) & (original_tmdb_merge["new_revenue"] != 0)])
# Out:
# 1205

# %% [markdown]
# But we do lose information about 75 movies if we just use info from TMDB.

# %%
len(original_tmdb_merge[(original_tmdb_merge["new_revenue"] == 0) & (original_tmdb_merge["revenue"] != 0)])
# Out:
# 75

# %% [markdown]
# So we'll use the available information and prioritise info from TMBD:

# %%
original_tmdb_merge["revenue"] = np.where(
    original_tmdb_merge["new_revenue"] == 0, 
    original_tmdb_merge["revenue"], 
    original_tmdb_merge["new_revenue"]
)
original_tmdb_merge = original_tmdb_merge.drop(columns="new_revenue")

# %% [markdown]
# ## Boxoffice Mojo
#
# We'll now merge with the Boxoffice Mojo data that we scraped

# %%
bo_mojo = pd.read_csv(f"{DATA_FOLDER}/boxoffice_mojo.csv").convert_dtypes()

# %%
bo_mojo
# Out:
#                              title  \
# 0                          Jumanji
# 1      Father of the Bride Part II
# 2                             Heat
# 3                          Sabrina
# 4                 Grumpier Old Men
# ...                            ...
# 45406                     Betrayal
# 45407          Century of Birthing
# 45408                      Subdued
# 45409             Satan Triumphant
# 45410                     Queerama
#
#                                                  tagline  \
# 0      When two kids find and play a magical board ga...
# 1      George Banks must deal not only with the pregn...
# 2      A group of professional bank robbers start to ...
# 3      An ugly duckling having undergone a remarkable...
# 4      John and Max resolve to save their beloved bai...
# ...                                                  ...
# 45406  Jayne Ferré needs to get out of Los Angeles fa...
# 45407  An artist struggles to finish his work. A stor...
# 45408  After her divorce Mina is in need to financial...
# 45409                                               <NA>
# 45410  Compilation of archive footage from 1919 to th...
#
#                                    genres        date  runtime    revenue  \
# 0      Adventure, Comedy, Family, Fantasy  1995-12-15      104  262821940
# 1                 Comedy, Family, Romance  1995-12-08      106   76594107
# 2                  Crime, Drama, Thriller  1995-12-15      170  187436818
# 3                  Comedy, Drama, Romance  1995-12-15      127   53696278
# 4                         Comedy, Romance  1995-12-22      101   71518503
# ...                                   ...         ...      ...        ...
# 45406             Action, Drama, Thriller        <NA>       90       <NA>
# 45407                               Drama        <NA>      360       <NA>
# 45408                      Drama, Romance        <NA>      103       <NA>
# 45409                               Drama        <NA>       87       <NA>
# 45410                  Documentary, Music  2017-07-28       70       2672
#
#          budget          director  \
# 0      65000000      Joe Johnston
# 1          <NA>     Charles Shyer
# 2          <NA>      Michael Mann
# 3      58000000    Sydney Pollack
# 4          <NA>     Howard Deutch
# ...         ...               ...
# 45406      <NA>    Mark L. Lester
# 45407      <NA>          Lav Diaz
# 45408      <NA>  Hamid Nematollah
# 45409      <NA>  Yakov Protazanov
# 45410      <NA>              <NA>
#
#                                                     cast  \
# 0      Robin Williams, Kirsten Dunst, Bonnie Hunt, Jo...
# 1      Steve Martin, Diane Keaton, Martin Short, Kimb...
# 2      Al Pacino, Robert De Niro, Val Kilmer, Jon Voight
# 3      Harrison Ford, Julia Ormond, Greg Kinnear, Nan...
# 4      Walter Matthau, Jack Lemmon, Ann-Margret, Soph...
# ...                                                  ...
# 45406  Erika Eleniak, Adam Baldwin, Julie du Page, Je...
# 45407  Perry Dizon, Angel Aquino, Bart Guingona, Haze...
# 45408  Leila Hatami, Elham Korda, Leila Moosavi, Kour...
# 45409  Ivan Mozzhukhin, Nathalie Lissenko, Polycarpe ...
# 45410                                               <NA>
#
#           production_companies    imdb_id
# 0      Sony Pictures Releasing  tt0113497
# 1          Walt Disney Studios  tt0113041
# 2                 Warner Bros.  tt0113277
# 3           Paramount Pictures  tt0114319
# 4                 Warner Bros.  tt0113228
# ...                        ...        ...
# 45406                     <NA>  tt0303758
# 45407                     <NA>  tt2028550
# 45408                     <NA>  tt6209470
# 45409                     <NA>  tt0008536
# 45410                     <NA>  tt6980792
#
# [45411 rows x 11 columns]

# %% [markdown]
# As before, we'll prefer information from the BoxOffice Mojo website when choosing between the two data sources.
#
# The tagline information in the BoxOffice Mojo dataset though is actually the description. We will keep both.

# %%
bo_mojo["budget"] = bo_mojo["budget"].fillna(0)
bo_mojo["revenue"] = bo_mojo["revenue"].fillna(0)
final_dataset = original_tmdb_merge.merge(bo_mojo, on="imdb_id", suffixes=("_original", "_bo_mojo"))
shared_columns = set(original_tmdb_merge.columns).intersection(set(bo_mojo.columns)).difference({"imdb_id"})
suffixed_shared_columns = [(col, f"{col}_original", f"{col}_bo_mojo") for col in shared_columns]

# %%
final_dataset.columns
# Out:
# Index(['id', 'title_original', 'tagline_original', 'description',
#        'genres_original', 'keywords', 'date_original', 'collection',
#        'runtime_original', 'revenue_original', 'budget_original',
#        'director_original', 'cast_original', 'production_companies_original',
#        'production_countries', 'popularity', 'average_vote', 'num_votes',
#        'language', 'imdb_id', 'poster_url', 'title_bo_mojo', 'tagline_bo_mojo',
#        'genres_bo_mojo', 'date_bo_mojo', 'runtime_bo_mojo', 'revenue_bo_mojo',
#        'budget_bo_mojo', 'director_bo_mojo', 'cast_bo_mojo',
#        'production_companies_bo_mojo'],
#       dtype='object')

# %%
def take_bomojo_of_column(col: str):
    return np.where(final_dataset[f"{col}_bo_mojo"].notna(), final_dataset[f"{col}_bo_mojo"], final_dataset[f"{col}_original"])

def take_original_of_column(col: str):
    return np.where(final_dataset[f"{col}_original"].notna(), final_dataset[f"{col}_original"], final_dataset[f"{col}_bo_mojo"])

final_dataset["runtime"] = take_bomojo_of_column("runtime")
final_dataset["date"] = take_bomojo_of_column("date")
final_dataset["title"] = take_bomojo_of_column("title")
final_dataset["director"] = take_bomojo_of_column("director")

final_dataset["production_companies"] = take_original_of_column("production_companies")
final_dataset["cast"] = take_original_of_column("cast")

final_dataset["revenue"] = np.where(final_dataset["revenue_bo_mojo"] != 0, final_dataset["revenue_bo_mojo"], final_dataset["revenue_original"])
final_dataset["budget"] = np.where(final_dataset["budget_bo_mojo"] != 0, final_dataset["budget_bo_mojo"], final_dataset["budget_original"])

extra_columns = list(map(list, zip(*suffixed_shared_columns)))
final_dataset["description2"] = final_dataset["tagline_bo_mojo"]
final_dataset["tagline"] = final_dataset["tagline_original"]
final_dataset = final_dataset.drop(columns=extra_columns[1] + extra_columns[2])

# %%
final_dataset.columns
# Out:
# Index(['id', 'description', 'keywords', 'collection', 'production_countries',
#        'popularity', 'average_vote', 'num_votes', 'language', 'imdb_id',
#        'poster_url', 'runtime', 'date', 'title', 'director',
#        'production_companies', 'cast', 'revenue', 'budget', 'description2',
#        'tagline'],
#       dtype='object')

# %%
def take_bomojo_of_column(col: str):
    return np.where(final_dataset[f"{col}_bo_mojo"].notna(), final_dataset[f"{col}_bo_mojo"], final_dataset[f"{col}_original"])

def take_original_of_column(col: str):
    return np.where(final_dataset[f"{col}_original"].notna(), final_dataset[f"{col}_original"], final_dataset[f"{col}_bo_mojo"])

final_dataset["runtime"] = take_bomojo_of_column("runtime")
final_dataset["date"] = take_bomojo_of_column("date")
final_dataset["title"] = take_bomojo_of_column("title")
final_dataset["director"] = take_bomojo_of_column("director")

final_dataset["production_companies"] = take_original_of_column("production_companies")
final_dataset["cast"] = take_original_of_column("cast")

final_dataset["revenue"] = np.where(final_dataset["revenue_bo_mojo"] != 0, final_dataset["revenue_bo_mojo"], final_dataset["revenue_original"])
final_dataset["budget"] = np.where(final_dataset["budget_bo_mojo"] != 0, final_dataset["budget_bo_mojo"], final_dataset["budget_original"])

extra_columns = list(map(list, zip(*suffixed_shared_columns)))
final_dataset["description2"] = final_dataset["tagline_bo_mojo"]
final_dataset["tagline"] = final_dataset["tagline_original"]
final_dataset = final_dataset.drop(columns=extra_columns[1] + extra_columns[2])

# %% [markdown]
# # Target definition

# %% [markdown]
# We define the following classification as our target variable:
# - Movie where $revenue \ge 4.5 \cdot budget$: super hit;
# - Movie where $4.5 \cdot budget \ge revenue \ge 2.5 \cdot budget$: blockbuster;
# - Movie where $2.5 \cdot budget \ge revenue \ge 1.5 \cdot budget$: minor success;
# - Movie where $budget \ge revenue \ge \frac{1}{3} \cdot budget$: flop;
# - Movie where $\frac{1}{3} \cdot budget \ge revenue$: box office bomb

# %%
def target_classification(revenue, budget) -> str:
    if revenue == 0 or budget == 0:
        return "unclassified"

    if revenue >= 4.5 * budget:
        return "super hit"
    if 4.5 * budget >= revenue >= 2.5 * budget:
        return "blockbuster"
    if 2.5 * budget >= revenue >= budget:
        return "minor success"
    if budget >= revenue >= 1/3 * budget:
        return "flop"
    if 1/3 * budget >= revenue:
        return "box office bomb"

# %%
final_dataset[(final_dataset["revenue"] != 0) & (final_dataset["budget"] != 0)][["revenue", "budget"]]
# Out:
#          revenue    budget
# 2        4257354   4000000
# 4      775512064  11000000
# 5      962859504  94000000
# 6      683088874  55000000
# 7      356296601  15000000
# ...          ...       ...
# 45282       4314    400000
# 45284   22757764  23000000
# 45348    9559524  25000000
# 45383     776522  15000000
# 45406      42832   1254040
#
# [7505 rows x 2 columns]

# %%
final_dataset["movie_classification"] = final_dataset.apply(lambda row: target_classification(row["revenue"], row["budget"]), axis=1)

# %%
valid_classifications = final_dataset["movie_classification"] != "unclassified"

alt.data_transformers.enable("json")
alt.Chart(final_dataset[valid_classifications], width=500).mark_bar().encode(
    x="movie_classification:N",
    y="count(movie_classification)"
)
# Out:
# alt.Chart(...)

# %%
f"Number of training data available: {valid_classifications.sum()}"
# Out:
# 'Number of training data available: 7505'

# %% [markdown]
# We obviously can't do much with so little data. We could think about deriving another classification based solely on the revenue, but this must be researched and adjusted to account for inflation, for example.
#
# So this will do for now.

# %%
final_dataset
# Out:
#            id                                        description  \
# 0           2  Taisto Kasurinen is a Finnish coal miner whose...
# 1           3  An episode in the life of Nikander, a garbage ...
# 2           5  It's Ted the Bellhop's first night on the job....
# 3           6  While racing to a boxing match, Frank, Mike, J...
# 4          11  Princess Leia is captured and held hostage by ...
# ...       ...                                                ...
# 45403  465044  A horror comedy spoofing conspiracy theory mov...
# 45404  467731  Fifteen-year-old girl Dotty Fisher is assaulte...
# 45405  468343  In the 1910s, beautiful young Silja loses both...
# 45406  468707                                                NaN
# 45407  469172  Manuel is a young boy who travels from long ag...
#
#                                                 keywords  \
# 0      underdog, prison, factory worker, prisoner, he...
# 1        salesclerk, helsinki, garbage, independent film
# 2      hotel, new year's eve, witch, bet, hotel room,...
# 3      chicago, drug dealer, boxing match, escape, on...
# 4      android, galaxy, hermit, death star, lightsabe...
# ...                                                  ...
# 45403                                                NaN
# 45404                                                NaN
# 45405                                                NaN
# 45406                              fantasy, youth, weird
# 45407                                                NaN
#
#                  collection             production_countries  popularity  \
# 0                       NaN                          Finland    3.860491
# 1                       NaN                          Finland    2.292110
# 2                       NaN         United States of America    9.026586
# 3                       NaN  Japan, United States of America    5.538671
# 4      Star Wars Collection         United States of America   42.149697
# ...                     ...                              ...         ...
# 45403                   NaN                   United Kingdom    0.281008
# 45404                   NaN         United States of America    0.001189
# 45405                   NaN                          Finland    0.001202
# 45406                   NaN                          Finland    0.347806
# 45407                   NaN                 France, Portugal    0.001097
#
#        average_vote  num_votes language    imdb_id  ...        date  \
# 0               7.1       44.0       fi  tt0094675  ...  1988-10-21
# 1               7.1       35.0       fi  tt0092149  ...  1986-10-16
# 2               6.5      539.0       en  tt0113101  ...  1995-12-22
# 3               6.4       79.0       en  tt0107286  ...  1993-10-15
# 4               8.1     6778.0       en  tt0076759  ...  1977-05-25
# ...             ...        ...      ...        ...  ...         ...
# 45403           0.0        0.0       en  tt5943940  ...  2017-06-28
# 45404           0.0        0.0       en  tt0507700  ...  1956-02-19
# 45405           0.0        0.0       fi  tt0133202  ...  1956-01-01
# 45406           8.0        1.0       fi  tt5742932  ...  2017-07-28
# 45407           0.0        0.0       pt  tt0089018  ...  1984-08-02
#
#                                     title  \
# 0                                   Ariel
# 1                     Shadows in Paradise
# 2                              Four Rooms
# 3                          Judgment Night
# 4      Star Wars: Episode IV - A New Hope
# ...                                   ...
# 45403                           Abduction
# 45404         Tragedy in a Temporary Town
# 45405            Silja - nuorena nukkunut
# 45406    Thick Lashes of Lauri Mäntyvaara
# 45407     Manuel on the Island of Wonders
#
#                                                 director  \
# 0                                         Aki Kaurismäki
# 1                                         Aki Kaurismäki
# 2      Allison Anders, Alexandre Rockwell, Robert Rod...
# 3                                        Stephen Hopkins
# 4                                           George Lucas
# ...                                                  ...
# 45403                           Maurice Smith, Mol Smith
# 45404                                       Sidney Lumet
# 45405                                       Jack Witikka
# 45406                                   Hannaleena Hauru
# 45407                                          Raúl Ruiz
#
#                                     production_companies  \
# 0      Villealfa Filmproduction Oy, Finnish Film Foun...
# 1                            Villealfa Filmproduction Oy
# 2                            Miramax Films, A Band Apart
# 3      Universal Pictures, Largo Entertainment, JVC E...
# 4      Lucasfilm, Twentieth Century Fox Film Corporation
# ...                                                  ...
# 45403                                               <NA>
# 45404                                               <NA>
# 45405                                               <NA>
# 45406                               Elokuvayhtiö Oy Aamu
# 45407  Institut National de l'Audiovisuel (INA), Radi...
#
#                                                     cast    revenue    budget  \
# 0      Turo Pajala, Susanna Haavisto, Matti Pellonpää...          0         0
# 1      Matti Pellonpää, Kati Outinen, Sakari Kuosmane...          0         0
# 2      Tim Roth, Antonio Banderas, Jennifer Beals, Ma...    4257354   4000000
# 3      Emilio Estevez, Cuba Gooding Jr., Denis Leary,...   12526677         0
# 4      Mark Hamill, Harrison Ford, Carrie Fisher, Pet...  775512064  11000000
# ...                                                  ...        ...       ...
# 45403  Karolina Antosik, Amelie Leroy, Tessa McGinn, ...          0         0
# 45404  Lloyd Bridges, Jack Warden, Rafael Campos, Rob...          0         0
# 45405  Heidi Krohn, Jussi Jurkka, Aku Korhonen, Pentt...          0         0
# 45406  Inka Haapamäki, Rosa Honkonen, Tiitus Rantala,...      42832   1254040
# 45407  Ruben de Freitas, Teresa Madruga, Fernando Hei...          0         0
#
#                                             description2  \
# 0      A Finnish man goes to the city to find a job a...
# 1      An episode in the life of Nikander, a garbage ...
# 2      Four interlocking tales that take place in a f...
# 3      Four friends on their way to a boxing match ge...
# 4      Luke Skywalker joins forces with a Jedi Knight...
# ...                                                  ...
# 45403  A horror comedy spoofing conspiracy theory mov...
# 45404  Fifteen-year-old girl Dotty Fisher is assaulte...
# 45405  In the 1910s, beautiful young Silja loses both...
# 45406  The love rebels are ready for battle. Satu and...
# 45407  Manuel's fantasy travel through Time goes from...
#
#                                                  tagline movie_classification
# 0                                                    NaN         unclassified
# 1                                                    NaN         unclassified
# 2      Twelve outrageous guests. Four scandalous requ...        minor success
# 3         Don't move. Don't whisper. Don't even breathe.         unclassified
# 4           A long time ago in a galaxy far, far away...            super hit
# ...                                                  ...                  ...
# 45403                                 Horrifically Funny         unclassified
# 45404                                                NaN         unclassified
# 45405                                                NaN         unclassified
# 45406                                                NaN      box office bomb
# 45407                                                NaN         unclassified
#
# [45408 rows x 22 columns]

# %%
final_dataset.to_csv(f"{DATA_FOLDER}/final_dataset.csv", index=False, header=True)
